# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_01_ai_gym.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 12: Reinforcement Learning**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).
# * Modified by uramoon@kw.ac.kr

# %% [markdown]
# # Module 12 Video Material
#
# * **Part 12.1: Introduction to the OpenAI Gym** [[Video]](https://www.youtube.com/watch?v=_KbUxgyisjM&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_01_ai_gym.ipynb)
# * Part 12.2: Introduction to Q-Learning [[Video]](https://www.youtube.com/watch?v=A3sYFcJY3lA&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_02_qlearningreinforcement.ipynb)
# * Part 12.3: Keras Q-Learning in the OpenAI Gym [[Video]](https://www.youtube.com/watch?v=qy1SJmsRhvM&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_03_keras_reinforce.ipynb)
# * Part 12.4: Atari Games with Keras Neural Networks [[Video]](https://www.youtube.com/watch?v=co0SwPWoZh0&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_04_atari.ipynb)
# * Part 12.5: Application of Reinforcement Learning [[Video]](https://www.youtube.com/watch?v=1jQPP3RfwMI&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_05_apply_rl.ipynb)

# %% [markdown]
# # Part 12.1: Introduction to the OpenAI Gymnasium
#
# Gymnasium은 OpenAI에서 만든 강화학습을 위한 API입니다.
#
# [OpenAI Gym](https://gym.openai.com/) aims to provide an easy-to-setup general-intelligence benchmark with various environments. The goal is to standardize how environments are defined in AI research publications to make published research more easily reproducible. The project claims to provide the user with a simple interface. As of June 2017, developers can only use Gym with Python.
#
# OpenAI gym is pip-installed onto your local machine. There are a few significant limitations to be aware of:
#
# * OpenAI Gym Atari only **directly** supports Linux and Macintosh
# * OpenAI Gym Atari can be used with Windows; however, it requires a particular [installation procedure](https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30)
# * OpenAI Gym can not directly render animated games in Google CoLab.
#
# Because OpenAI Gym requires a graphics display, an embedded video is the only way to display Gym in Google CoLab. The presentation of OpenAI Gym game animations in Google CoLab is discussed later in this module.
#
# ## OpenAI Gym Leaderboard
#
# The OpenAI Gym does have a leaderboard, similar to Kaggle; however, the OpenAI Gym's leaderboard is much more informal compared to Kaggle. The user's local machine performs all scoring. As a result, the OpenAI gym's leaderboard is strictly an "honor system."  The leaderboard is maintained in the following GitHub repository:
#
# * [OpenAI Gym Leaderboard](https://github.com/openai/gym/wiki/Leaderboard)
#
# You must provide a write-up with sufficient instructions to reproduce your result if you submit a score. A video of your results is suggested but not required.
#
# ## Looking at Gym Environments
#
# Gym은 강화학습을 수행할 수 있는 환경을 제공합니다.
# The centerpiece of Gym is the environment, which defines the "game" in which your reinforcement algorithm will compete. An environment does not need to be a game; however, it describes the following game-like features:
# * **action space**: 매 스텝에서 취할 수 있는 행동 목록 제공
# * **observation space**: 현재 관측 가능한 상태 제공
#
# Before we begin to look at Gym, it is essential to understand some of the terminology used by this library.
#
# * **Agent** - 매 스텝 행동을 취하는 기계 학습 프로그램, 행동에 따라 다음 상태가 달라집니다.
# * **Episode** - 연속된 스텝들의 모음. 에이전트가 실패하거나 미리 정해놓은 최대 스텝에 도달하면 에피소드는 종료합니다.
# * **Render** - Gym은 frame단위로 에피소드에서 발생한 일들을 그릴 수 있습니다.
# * **Reward** - 에피소드가 끝날 때 행동에 따라 에이전트는 보상을 받을 수 있습니다.
# * **Non-deterministic** - 어떤 환경에서는 보상이 확률적으로 주어집니다. 예) 복권
#
# It is important to note that many gym environments specify that they are not non-deterministic even though they use random numbers to process actions. Based on the gym GitHub issue tracker, a non-deterministic property means a deterministic environment behaves randomly. Even when you give the environment a consistent seed value, this behavior is confirmed. The program can use the seed method of an environment to seed the random number generator for the environment.
#
# The Gym library allows us to query some of these attributes from environments. I created the following function to query gym environments.

# %%
# 현재 버전은 Colab에서 문제가 있어 구버전 설치
# !pip install gym==0.15.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gym==0.15.3
#   Downloading gym-0.15.3.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gym==0.15.3) (1.10.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.10/dist-packages (from gym==0.15.3) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gym==0.15.3) (1.16.0)
# Collecting pyglet<=1.3.2,>=1.2.0 (from gym==0.15.3)
#   Downloading pyglet-1.3.2-py2.py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.4 MB/s eta 0:00:00
# Collecting cloudpickle~=1.2.0 (from gym==0.15.3)
#   Downloading cloudpickle-1.2.2-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from pyglet<=1.3.2,>=1.2.0->gym==0.15.3) (0.18.3)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.15.3-py3-none-any.whl size=1644944 sha256=4196e7142fb329519dd610bc462095d3418b5a4306ad5eb0b43d41aaf3b64561
#   Stored in directory: /root/.cache/pip/wheels/dc/4c/1c/25048a3f2e8540c60bbba0c25d8400f959205db1048431873a
# Successfully built gym
# Installing collected packages: cloudpickle, pyglet, gym
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 2.2.1
#     Uninstalling cloudpickle-2.2.1:
#       Successfully uninstalled cloudpickle-2.2.1
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# distributed 2022.12.1 requires cloudpickle>=1.5.0, but you have cloudpickle 1.2.2 which is incompatible.
# tensorflow-probability 0.20.1 requires cloudpickle>=1.3, but you have cloudpickle 1.2.2 which is incompatible.
# Successfully installed cloudpickle-1.2.2 gym-0.15.3 pyglet-1.3.2

# %%
import gym

# name에 해당하는 환경의 정보를 출력해주는 함수
def query_environment(name):
    env = gym.make(name)
    spec = gym.spec(name)
    print(f"Action Space: {env.action_space}")
    print(f"Observation Space: {env.observation_space}")
    print(f"Max Episode Steps: {spec.max_episode_steps}")
    print(f"Nondeterministic: {spec.nondeterministic}")
    print(f"Reward Range: {env.reward_range}")
    print(f"Reward Threshold: {spec.reward_threshold}")

# %% [markdown]
# ## MountainCar 환경 살펴보기
# We will look at the **MountainCar-v0** environment, which challenges an underpowered car to escape the valley between two mountains.  The following code describes the Mountian Car environment.
#
# <img src='https://gymnasium.farama.org/_images/mountain_car.gif' width="360">

# %%
query_environment("MountainCar-v0")
# Out:
# Action Space: Discrete(3)
# Observation Space: Box(2,)
# Max Episode Steps: 200
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: -110.0

# %% [markdown]
# ### TODO: MountainCar 질문에 대한 답 작성
# Hint: https://gymnasium.farama.org/environments/classic_control/mountain_car/

# %%
# Q: MountainCar-v0에서는 매 스텝 어떤 행동을 취할 수 있을까요? 각 행동의 의미를 기재하세요.
# A: 0: Accelerate to the left, 1: Don’t accelerate, 2: Accelerate to the right

# Q: 관측할 수 있는 것은 실수 두 개인데 각 실수는 무엇을 의미할까요?
# A: 첫 번째 실수: 자동차의 x축 위치(position of the car along the x-axis), 두 번째 실수: 자동차의 속도(velocity of the car)

# Q: 강화학습의 목표는 최대한 많은 리워드를 받는 것입니다. 
# 이 환경에서는 골인 지점에 있지 않으면 매 스텝 -1의 리워드가 주어지는데 어떻게 행동해야 할까요?
# A: 오른쪽 언덕 꼭대기에 올라갈 수 있도록 보상을 조금씩 주어야한다.
# Starting State : 차의 위치는 [-0.6, -0.4]에서 균일한 무작위 값을 할당 받는다. 차의 시작 속도는 항상 0으로 핟당된다.
# Episode End : 종료(자동차의 위치가 0.5 이상인 경우 (=오른쪽 언덕 꼭대기의 목표 위치)), 중단(에피소드 길이가 200이 될 때.)

# %% [markdown]
# ## CartPole 환경 살펴보기
# <img src="https://gymnasium.farama.org/_images/cart_pole.gif" width="360">

# %%
query_environment("CartPole-v1")
# Out:
# Action Space: Discrete(2)
# Observation Space: Box(4,)
# Max Episode Steps: 500
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: 475.0

# %% [markdown]
# ## TODO: CartPole 질문에 대한 답 작성
# Hint: https://gymnasium.farama.org/environments/classic_control/cart_pole/

# %%
# Q: CartPole-v1에서는 매 스텝 어떤 행동을 취할 수 있을까요? 각 행동의 의미를 기재하세요.
# A: 0: Push cart to the left, 1: Push cart to the right

# Q: 관측할 수 있는 것은 실수 네 개인데 각 실수는 무엇을 의미할까요?
# A: 첫 번째 실수: Cart 위치, 두 번째 실수: Cart 속도, 세 번째 실수: Pole(극) 각도, 네 번째 실수: Pole(극) 각속도

# Q: Observation Space에 기재된 에피소드 종료 조건 세 가지는 무엇일까요?
# A: 첫 번째 종료조건: Pole 각도가 ±12°보다 클 경우, 두 번째 종료조건: Cart 위치가 ±2.4보다 클 경우 (Cart 중앙이 디스플레이의 가장자리에 닿습니다), 세 번째 종료조건: 에피소드 길이는 500 이상일 경우

# Q: 강화학습의 목표는 최대한 많은 리워드를 받는 것입니다. 
# 이 환경에서는 매 스텝 +1의 리워드가 주어지는데 어떻게 행동해야 할까요?
# A: 계속 유지하고 있다면 보상을 계속 준다.
# 목표는 가능한 한 오랫동안 막대를 세우는 것이고, 각 단계마다(종료 단계 포함) +1의 보상이 주어진다. 보상 임계값은 v1의 경우 475입니다.

# %% [markdown]
# ## Atari ROM 파일 다운로드
#
# Note: If you see a warning above, you can safely ignore it; it is a relatively minor bug in OpenAI Gym.
#
# Atari games, like breakout, can use an observation space that is either equal to the size of the Atari screen (210x160) or even use the RAM of the Atari (128 bytes) to determine the state of the game.  Yes, that's bytes, not kilobytes!

# %%
# !wget http://www.atarimania.com/roms/Roms.rar 
# !unrar x -o+ /content/Roms.rar >/dev/nul
# !pip install atari_py
# !python -m atari_py.import_roms /content/ROMS >/dev/nul
# Out:
# --2023-05-26 06:41:10--  http://www.atarimania.com/roms/Roms.rar
# Resolving www.atarimania.com (www.atarimania.com)... 195.154.81.199
# Connecting to www.atarimania.com (www.atarimania.com)|195.154.81.199|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19612325 (19M) [application/x-rar-compressed]
# Saving to: ‘Roms.rar’
#
# Roms.rar            100%[===================>]  18.70M  3.58MB/s    in 5.3s
#
# 2023-05-26 06:41:15 (3.54 MB/s) - ‘Roms.rar’ saved [19612325/19612325]
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting atari_py
#   Downloading atari-py-0.2.9.tar.gz (540 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.6/540.6 kB 17.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from atari_py) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from atari_py) (1.16.0)
# Building wheels for collected packages: atari_py
#   Building wheel for atari_py (setup.py) ... done
#   Created wheel for atari_py: filename=atari_py-0.2.9-cp310-cp310-linux_x86_64.whl size=2856238 sha256=a1767f57ae5cabe89470a8a0e6248b15d0188e43b46b31a7b629479fdb974ab9
#   Stored in directory: /root/.cache/pip/wheels/75/6f/04/1f3bf5255580101e16ff487564354dddcdd23ec3b43b775b7a
# Successfully built atari_py
# Installing collected packages: atari_py
# Successfully installed atari_py-0.2.9

# %% [markdown]
# ## 두 가지 버전의 벽돌깨기 (Breakout) 게임 환경
# <img src="https://gymnasium.farama.org/_images/breakout.gif" width="160"><br>
# https://gymnasium.farama.org/environments/atari/breakout/

# %%
# 인간 플레이어와 동일하게 210 x 160, 3채널 컬러 이미지를 관측하는 환경 (각 픽셀값은 0 ~ 255)
query_environment("Breakout-v0")
# Out:
# Action Space: Discrete(4)
# Observation Space: Box(210, 160, 3)
# Max Episode Steps: 10000
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: None

# %%
# Atari 게임기의 128 bytes 메모리를 관측하는 환경 (각 바이트는 0 ~ 255)
query_environment("Breakout-ram-v0")
# Out:
# Action Space: Discrete(4)
# Observation Space: Box(128,)
# Max Episode Steps: 10000
# Nondeterministic: False
# Reward Range: (-inf, inf)
# Reward Threshold: None

# %% [markdown]
# ## Render OpenAI Gym Environments from CoLab
#
# 그려봅시다!
#
# It is possible to visualize the game your agent is playing, even on CoLab. This section provides information on generating a video in CoLab that shows you an episode of the game your agent is playing. I based this video process on suggestions found [here](https://colab.research.google.com/drive/1flu31ulJlgiRL1dnN2ir8wGh9p7Zij2t).
#
# Begin by installing **pyvirtualdisplay** and **python-opengl**.

# %%
# 이해할 필요 없습니다.
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# %% [markdown]
# Next, we install the needed requirements to display an Atari game.

# %%
# 이해할 필요 없습니다.
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[atari] > /dev/null 2>&1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (67.7.2)
# Collecting setuptools
#   Downloading setuptools-67.8.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.4 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed setuptools-67.8.0

# %% [markdown]
# Next, we define the functions used to show the video by adding it to the CoLab notebook.

# %%
# 이해할 필요 없습니다.
import gym
from gym.wrappers import Monitor
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

display = Display(visible=0, size=(1400, 900))
display.start()

"""
Utility functions to enable video recording of gym environment 
and displaying it.
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
    mp4list = glob.glob('video/*.mp4')
    if len(mp4list) > 0:
        mp4 = mp4list[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

def wrap_env(env):
    env = Monitor(env, './video', force=True)    
    return env

# %% [markdown]
# ### 아틀란티스 게임에서 랜덤 에이전트의 행동 그려보기
#
# 아틀란티스라는 게임은 플레이어가 매 스텝 다음의 행동을 취할 수 있습니다.
# 0. 아무것도 안함
# 1. 가운데 총 발사
# 2. 오른쪽 총 발사
# 3. 왼쪽 총 발사
#
# 매 번 랜덤한 행동을 취하는 에이전트의 플레이를 그려보겠습니다.

# %%
env = wrap_env(gym.make("Atlantis-v0"))
observation = env.reset()

while True:
    # 매 스텝 다음을 수행

    # 그리기
    env.render()

    # 액션 정하기
    action = env.action_space.sample()  # 랜덤하게 설정

    # 행동에 따른 새로운 관측, 리워드, 에피소드 종료 여부, 종료에 관한 정보를 반환
    observation, reward, done, info = env.step(action)

    if done:
        break

env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ## TODO: Kung Fu Master 랜덤 에이전트 만들기
# https://gymnasium.farama.org/environments/atari/kung_fu_master/<br>
# 매 스텝 무작위 액션을 취하는 에이전트를 만들어 플레이 장면을 그려보세요.

# %%
env = wrap_env(gym.make("KungFuMaster-v4"))

#TODO
observation = env.reset()

i=0
while True:
    # 매 스텝 다음을 수행
    i += 1

    # 그리기
    env.render()

    # 액션 정하기
    action = env.action_space.sample()  # 랜덤하게 설정

    # 행동에 따른 새로운 관측, 리워드, 에피소드 종료 여부, 종료에 관한 정보를 반환
    observation, reward, done, info = env.step(action)
    print(f"Step {i}: Previous action={action}, Observation={observation}, Reward={reward}")

    if done:
        break

env.close()
show_video()

# %% [markdown]
# ## TODO: 직접 CartPole 에이전트 만들기
# https://gymnasium.farama.org/environments/classic_control/cart_pole/
# <br>
# 단순 프로그래밍으로 500 스텝까지 살아남는 에이전트를 만들어보세요.
#
# 500 스텝 이전에 종료 끝났다면 위에서 작성한 CartPole 문제에 대한 대답을 참고하여 <br>더 오랜 시간 살아남을 수 있도록 만들어 보세요.

# %%
env = wrap_env(gym.make("CartPole-v1"))
observation = env.reset()

i = 0
done = False
while not done:   
    i += 1

    cart_pos = observation[0]
    cart_vel = observation[1]
    pole_angle = observation[2]
    pole_angle_vel = observation[3]


    # 각도만 보는 에이전트
    if observation[2] < 0: 
        print("a")
        action = 0 # 왼쪽으로 기울어졌으면 왼쪽으로
        if pole_angle_vel > 1.5:
            print("bb")
            action = 1
    else: 
        print("b")
        action = 1                  # 오른쪽으로 기울어졌으면 오른쪽으로 
        if pole_angle_vel < -1.5:
            print("aa")
            action = 0

    

    # 행동에 따른 새로운 관측, 리워드, 에피소드 종료 여부, 종료에 관한 정보를 반환
    observation, reward, done, info = env.step(action)
    print(f"Step {i}: Previous action={action}, Observation={observation}, Reward={reward}")

    env.render()

    if done:    
        break

env.close()
show_video()
# Out:
# a
# Step 1: Previous action=0, Observation=[ 0.02328066 -0.18424369 -0.03781969  0.30076189], Reward=1.0
# a
# Step 2: Previous action=0, Observation=[ 0.01959579 -0.37880675 -0.03180445  0.58128145], Reward=1.0
# a
# Step 3: Previous action=0, Observation=[ 0.01201966 -0.57346897 -0.02017882  0.86377817], Reward=1.0
# a
# Step 4: Previous action=0, Observation=[ 5.50276175e-04 -7.68310486e-01 -2.90325851e-03  1.15004878e+00], Reward=1.0
# a
# Step 5: Previous action=0, Observation=[-0.01481593 -0.96339443  0.02009772  1.4418199 ], Reward=1.0
# b
# Step 6: Previous action=1, Observation=[-0.03408382 -0.76852563  0.04893412  1.15548407], Reward=1.0
# b
# Step 7: Previous action=1, Observation=[-0.04945433 -0.57407467  0.0720438   0.87853767], Reward=1.0
# b
# Step 8: Previous action=1, Observation=[-0.06093583 -0.38000174  0.08961455  0.60934597], Reward=1.0
# b
# Step 9: Previous action=1, Observation=[-0.06853586 -0.18623926  0.10180147  0.34617994], Reward=1.0
# b
# Step 10: Previous action=1, Observation=[-0.07226065  0.00729841  0.10872507  0.08725441], Reward=1.0
# b
# Step 11: Previous action=1, Observation=[-0.07211468  0.20070751  0.11047016 -0.16924397], Reward=1.0
# b
# Step 12: Previous action=1, Observation=[-0.06810053  0.39408912  0.10708528 -0.425136  ], Reward=1.0
# b
# Step 13: Previous action=1, Observation=[-0.06021875  0.58754417  0.09858256 -0.68223343], Reward=1.0
# b
# Step 14: Previous action=1, Observation=[-0.04846786  0.7811689   0.08493789 -0.942324  ], Reward=1.0
# b
# Step 15: Previous action=1, Observation=[-0.03284449  0.97504996  0.06609141 -1.20715544], Reward=1.0
# b
# Step 16: Previous action=1, Observation=[-0.01334349  1.16925873  0.0419483  -1.47841586], Reward=1.0
# b
# Step 17: Previous action=1, Observation=[ 0.01004169  1.36384417  0.01237998 -1.75770808], Reward=1.0
# b
# aa
# Step 18: Previous action=0, Observation=[ 0.03731857  1.1685842  -0.02277418 -1.46120093], Reward=1.0
# a
# Step 19: Previous action=0, Observation=[ 0.06069026  0.9737487  -0.0519982  -1.17571851], Reward=1.0
# a
# Step 20: Previous action=0, Observation=[ 0.08016523  0.77933947 -0.07551257 -0.8997794 ], Reward=1.0
# a
# Step 21: Previous action=0, Observation=[ 0.09575202  0.58531758 -0.09350816 -0.63175552], Reward=1.0
# a
# Step 22: Previous action=0, Observation=[ 0.10745837  0.39161608 -0.10614327 -0.36992396], Reward=1.0
# a
# Step 23: Previous action=0, Observation=[ 0.11529069  0.19814972 -0.11354175 -0.11250519], Reward=1.0
# a
# Step 24: Previous action=0, Observation=[ 0.11925369  0.00482235 -0.11579185  0.14230904], Reward=1.0
# a
# Step 25: Previous action=0, Observation=[ 0.11935013 -0.18846729 -0.11294567  0.39633519], Reward=1.0
# a
# Step 26: Previous action=0, Observation=[ 0.11558079 -0.38182073 -0.10501896  0.65138193], Reward=1.0
# a
# Step 27: Previous action=0, Observation=[ 0.10794437 -0.5753354  -0.09199133  0.90923586], Reward=1.0
# a
# Step 28: Previous action=0, Observation=[ 0.09643766 -0.76909995 -0.07380661  1.17164643], Reward=1.0
# a
# Step 29: Previous action=0, Observation=[ 0.08105567 -0.96318878 -0.05037368  1.44030763], Reward=1.0
# a
# Step 30: Previous action=0, Observation=[ 0.06179189 -1.15765535 -0.02156753  1.71683387], Reward=1.0
# a
# bb
# Step 31: Previous action=1, Observation=[ 0.03863878 -0.96229285  0.01276915  1.41751791], Reward=1.0
# b
# Step 32: Previous action=1, Observation=[ 0.01939293 -0.7673313   0.04111951  1.12885346], Reward=1.0
# b
# Step 33: Previous action=1, Observation=[ 0.0040463  -0.57277135  0.06369658  0.84934595], Reward=1.0
# b
# Step 34: Previous action=1, Observation=[-0.00740913 -0.37857321  0.0806835   0.5773536 ], Reward=1.0
# b
# Step 35: Previous action=1, Observation=[-0.01498059 -0.18466931  0.09223057  0.31113917], Reward=1.0
# b
# Step 36: Previous action=1, Observation=[-0.01867398  0.00902589  0.09845335  0.04890861], Reward=1.0
# b
# Step 37: Previous action=1, Observation=[-0.01849346  0.20260835  0.09943152 -0.21116037], Reward=1.0
# b
# Step 38: Previous action=1, Observation=[-0.01444129  0.39617844  0.09520832 -0.47089665], Reward=1.0
# b
# Step 39: Previous action=1, Observation=[-0.00651772  0.58983571  0.08579038 -0.73211799], Reward=1.0
# b
# Step 40: Previous action=1, Observation=[ 0.00527899  0.783674    0.07114802 -0.99661466], Reward=1.0
# b
# Step 41: Previous action=1, Observation=[ 0.02095247  0.97777614  0.05121573 -1.26613139], Reward=1.0
# b
# Step 42: Previous action=1, Observation=[ 0.04050799  1.17220765  0.0258931  -1.54234539], Reward=1.0
# b
# aa
# Step 43: Previous action=0, Observation=[ 0.06395215  0.97678419 -0.00495381 -1.24169674], Reward=1.0
# a
# Step 44: Previous action=0, Observation=[ 0.08348783  0.78172618 -0.02978774 -0.95056973], Reward=1.0
# a
# Step 45: Previous action=0, Observation=[ 0.09912235  0.58701756 -0.04879913 -0.66739266], Reward=1.0
# a
# Step 46: Previous action=0, Observation=[ 0.11086271  0.392607   -0.06214699 -0.39046522], Reward=1.0
# a
# Step 47: Previous action=0, Observation=[ 0.11871485  0.1984196  -0.06995629 -0.1180059 ], Reward=1.0
# a
# Step 48: Previous action=0, Observation=[ 0.12268324  0.00436608 -0.07231641  0.15181203], Reward=1.0
# a
# Step 49: Previous action=0, Observation=[ 0.12277056 -0.18964987 -0.06928017  0.42083282], Reward=1.0
# a
# Step 50: Previous action=0, Observation=[ 0.11897756 -0.38372533 -0.06086351  0.69089557], Reward=1.0
# a
# Step 51: Previous action=0, Observation=[ 0.11130305 -0.57795231 -0.0470456   0.96381376], Reward=1.0
# a
# Step 52: Previous action=0, Observation=[ 0.09974401 -0.7724117  -0.02776933  1.24135381], Reward=1.0
# a
# Step 53: Previous action=0, Observation=[ 0.08429577 -0.96716636 -0.00294225  1.52521004], Reward=1.0
# a
# bb
# Step 54: Previous action=1, Observation=[ 0.06495245 -0.77200902  0.02756195  1.23161027], Reward=1.0
# b
# Step 55: Previous action=1, Observation=[ 0.04951227 -0.57725218  0.05219416  0.94768816], Reward=1.0
# b
# Step 56: Previous action=1, Observation=[ 0.03796722 -0.38287042  0.07114792  0.67185069], Reward=1.0
# b
# Step 57: Previous action=1, Observation=[ 0.03030981 -0.18880584  0.08458493  0.40239013], Reward=1.0
# b
# Step 58: Previous action=1, Observation=[0.0265337  0.00502093 0.09263274 0.13752775], Reward=1.0
# b
# Step 59: Previous action=1, Observation=[ 0.02663412  0.19870243  0.09538329 -0.12455384], Reward=1.0
# b
# Step 60: Previous action=1, Observation=[ 0.03060817  0.39233765  0.09289221 -0.38568623], Reward=1.0
# b
# Step 61: Previous action=1, Observation=[ 0.03845492  0.58602657  0.08517849 -0.64769594], Reward=1.0
# b
# Step 62: Previous action=1, Observation=[ 0.05017545  0.779865    0.07222457 -0.91238724], Reward=1.0
# b
# Step 63: Previous action=1, Observation=[ 0.06577275  0.9739394   0.05397683 -1.18152433], Reward=1.0
# b
# Step 64: Previous action=1, Observation=[ 0.08525154  1.16832083  0.03034634 -1.45681035], Reward=1.0
# b
# Step 65: Previous action=1, Observation=[ 1.08617954e-01  1.36305754e+00  1.21013198e-03 -1.73986047e+00], Reward=1.0
# b
# aa
# Step 66: Previous action=0, Observation=[ 0.1358791   1.16792183 -0.03358708 -1.44680134], Reward=1.0
# a
# Step 67: Previous action=0, Observation=[ 0.15923754  0.97322869 -0.0625231  -1.16479909], Reward=1.0
# a
# Step 68: Previous action=0, Observation=[ 0.17870212  0.77897386 -0.08581909 -0.892356  ], Reward=1.0
# a
# Step 69: Previous action=0, Observation=[ 0.19428159  0.58511427 -0.10366621 -0.62783664], Reward=1.0
# a
# Step 70: Previous action=0, Observation=[ 0.20598388  0.39158026 -0.11622294 -0.36951742], Reward=1.0
# a
# Step 71: Previous action=0, Observation=[ 0.21381548  0.19828489 -0.12361329 -0.11562307], Reward=1.0
# a
# Step 72: Previous action=0, Observation=[ 0.21778118  0.00513098 -0.12592575  0.13564721], Reward=1.0
# a
# Step 73: Previous action=0, Observation=[ 0.2178838  -0.18798341 -0.1232128   0.38610072], Reward=1.0
# a
# Step 74: Previous action=0, Observation=[ 0.21412413 -0.38116051 -0.11549079  0.63753665], Reward=1.0
# a
# Step 75: Previous action=0, Observation=[ 0.20650092 -0.57449868 -0.10274006  0.89173312], Reward=1.0
# a
# Step 76: Previous action=0, Observation=[ 0.19501095 -0.76808811 -0.08490539  1.15043357], Reward=1.0
# a
# Step 77: Previous action=0, Observation=[ 0.17964919 -0.96200569 -0.06189672  1.41532992], Reward=1.0
# a
# Step 78: Previous action=0, Observation=[ 0.16040907 -1.15630871 -0.03359012  1.68804029], Reward=1.0
# a
# bb
# Step 79: Previous action=1, Observation=[ 1.37282898e-01 -9.60814883e-01  1.70680940e-04  1.38509133e+00], Reward=1.0
# b
# Step 80: Previous action=1, Observation=[ 0.1180666  -0.76569506  0.02787251  1.09246178], Reward=1.0
# b
# Step 81: Previous action=1, Observation=[ 0.1027527  -0.57095125  0.04972174  0.80865298], Reward=1.0
# b
# Step 82: Previous action=1, Observation=[ 0.09133367 -0.37654464  0.0658948   0.53201563], Reward=1.0
# b
# Step 83: Previous action=1, Observation=[ 0.08380278 -0.18240839  0.07653512  0.2608023 ], Reward=1.0
# b
# Step 84: Previous action=1, Observation=[ 0.08015461  0.01154232  0.08175116 -0.00679276], Reward=1.0
# b
# Step 85: Previous action=1, Observation=[ 0.08038546  0.20540247  0.08161531 -0.27260373], Reward=1.0
# b
# Step 86: Previous action=1, Observation=[ 0.08449351  0.39927076  0.07616323 -0.53846991], Reward=1.0
# b
# Step 87: Previous action=1, Observation=[ 0.09247892  0.59324399  0.06539383 -0.8062159 ], Reward=1.0
# b
# Step 88: Previous action=1, Observation=[ 0.1043438   0.78741154  0.04926952 -1.07763262], Reward=1.0
# b
# Step 89: Previous action=1, Observation=[ 0.12009204  0.98184933  0.02771686 -1.35445599], Reward=1.0
# b
# Step 90: Previous action=1, Observation=[ 1.39729022e-01  1.17661264e+00  6.27743060e-04 -1.63834104e+00], Reward=1.0
# b
# aa
# Step 91: Previous action=0, Observation=[ 0.16326127  0.98148333 -0.03213908 -1.34546258], Reward=1.0
# a
# Step 92: Previous action=0, Observation=[ 0.18289094  0.78677994 -0.05904833 -1.06300558], Reward=1.0
# a
# Step 93: Previous action=0, Observation=[ 0.19862654  0.59248732 -0.08030844 -0.7894247 ], Reward=1.0
# a
# Step 94: Previous action=0, Observation=[ 0.21047629  0.39855471 -0.09609693 -0.52304866], Reward=1.0
# a
# Step 95: Previous action=0, Observation=[ 0.21844738  0.2049073  -0.10655791 -0.26212674], Reward=1.0
# a
# Step 96: Previous action=0, Observation=[ 0.22254553  0.01145499 -0.11180044 -0.00486292], Reward=1.0
# a
# Step 97: Previous action=0, Observation=[ 0.22277463 -0.18190081 -0.1118977   0.25055915], Reward=1.0
# a
# Step 98: Previous action=0, Observation=[ 0.21913661 -0.37526177 -0.10688652  0.50595735], Reward=1.0
# a
# Step 99: Previous action=0, Observation=[ 0.21163138 -0.56872799 -0.09676737  0.7631357 ], Reward=1.0
# a
# Step 100: Previous action=0, Observation=[ 0.20025682 -0.76239342 -0.08150466  1.02386957], Reward=1.0
# a
# Step 101: Previous action=0, Observation=[ 0.18500895 -0.95634084 -0.06102727  1.2898891 ], Reward=1.0
# a
# Step 102: Previous action=0, Observation=[ 0.16588213 -1.15063586 -0.03522948  1.56285821], Reward=1.0
# a
# bb
# Step 103: Previous action=1, Observation=[ 0.14286941 -0.95511077 -0.00397232  1.25939722], Reward=1.0
# a
# Step 104: Previous action=0, Observation=[ 0.1237672  -1.15018167  0.02121562  1.55083341], Reward=1.0
# b
# Step 105: Previous action=1, Observation=[ 0.10076356 -0.95532053  0.05223229  1.26484441], Reward=1.0
# b
# Step 106: Previous action=1, Observation=[ 0.08165715 -0.7609036   0.07752918  0.98896603], Reward=1.0
# b
# Step 107: Previous action=1, Observation=[ 0.06643908 -0.56690033  0.0973085   0.72160602], Reward=1.0
# b
# Step 108: Previous action=1, Observation=[ 0.05510108 -0.37324952  0.11174062  0.46106755], Reward=1.0
# b
# Step 109: Previous action=1, Observation=[ 0.04763608 -0.1798696   0.12096197  0.20559011], Reward=1.0
# b
# Step 110: Previous action=1, Observation=[ 0.04403869  0.01333359  0.12507378 -0.04662091], Reward=1.0
# b
# Step 111: Previous action=1, Observation=[ 0.04430536  0.2064608   0.12414136 -0.29737291], Reward=1.0
# b
# Step 112: Previous action=1, Observation=[ 0.04843458  0.39961461  0.1181939  -0.54847007], Reward=1.0
# b
# Step 113: Previous action=1, Observation=[ 0.05642687  0.59289519  0.1072245  -0.80170007], Reward=1.0
# b
# Step 114: Previous action=1, Observation=[ 0.06828478  0.78639609  0.0911905  -1.05882086], Reward=1.0
# b
# Step 115: Previous action=1, Observation=[ 0.0840127   0.98019948  0.07001408 -1.32154521], Reward=1.0
# b
# Step 116: Previous action=1, Observation=[ 0.10361669  1.17437027  0.04358317 -1.5915205 ], Reward=1.0
# b
# aa
# Step 117: Previous action=0, Observation=[ 0.12710409  0.9787589   0.01175276 -1.28557268], Reward=1.0
# b
# Step 118: Previous action=1, Observation=[ 0.14667927  1.17372929 -0.01395869 -1.57455284], Reward=1.0
# a
# Step 119: Previous action=0, Observation=[ 0.17015386  0.97877652 -0.04544975 -1.28625589], Reward=1.0
# a
# Step 120: Previous action=0, Observation=[ 0.18972939  0.78426154 -0.07117486 -1.00814234], Reward=1.0
# a
# Step 121: Previous action=0, Observation=[ 0.20541462  0.5901582  -0.09133771 -0.73863225], Reward=1.0
# a
# Step 122: Previous action=0, Observation=[ 0.21721778  0.39640829 -0.10611036 -0.47603478], Reward=1.0
# a
# Step 123: Previous action=0, Observation=[ 0.22514595  0.2029321  -0.11563105 -0.21859073], Reward=1.0
# a
# Step 124: Previous action=0, Observation=[ 0.22920459  0.00963662 -0.12000287  0.03549649], Reward=1.0
# a
# Step 125: Previous action=0, Observation=[ 0.22939732 -0.18357832 -0.11929294  0.28803836], Reward=1.0
# a
# Step 126: Previous action=0, Observation=[ 0.22572576 -0.376815   -0.11353217  0.54084438], Reward=1.0
# a
# Step 127: Previous action=0, Observation=[ 0.21818946 -0.57017343 -0.10271528  0.79570801], Reward=1.0
# a
# Step 128: Previous action=0, Observation=[ 0.20678599 -0.76374706 -0.08680112  1.05439287], Reward=1.0
# a
# Step 129: Previous action=0, Observation=[ 0.19151105 -0.95761782 -0.06571326  1.31861667], Reward=1.0
# a
# Step 130: Previous action=0, Observation=[ 0.17235869 -1.15185016 -0.03934093  1.59003056], Reward=1.0
# a
# bb
# Step 131: Previous action=1, Observation=[ 0.14932169 -0.95628374 -0.00754032  1.28534465], Reward=1.0
# a
# Step 132: Previous action=0, Observation=[ 0.13019601 -1.15130889  0.01816657  1.57565723], Reward=1.0
# b
# Step 133: Previous action=1, Observation=[ 0.10716983 -0.95640813  0.04967972  1.288695  ], Reward=1.0
# b
# Step 134: Previous action=1, Observation=[ 0.08804167 -0.76195211  0.07545362  1.01197069], Reward=1.0
# b
# Step 135: Previous action=1, Observation=[ 0.07280263 -0.56791354  0.09569303  0.74390328], Reward=1.0
# b
# Step 136: Previous action=1, Observation=[ 0.06144436 -0.37423339  0.1105711   0.48280306], Reward=1.0
# b
# Step 137: Previous action=1, Observation=[ 0.05395969 -0.18083152  0.12022716  0.22691353], Reward=1.0
# b
# Step 138: Previous action=1, Observation=[ 0.05034306  0.01238542  0.12476543 -0.02555805], Reward=1.0
# b
# Step 139: Previous action=1, Observation=[ 0.05059077  0.2055178   0.12425427 -0.27641882], Reward=1.0
# b
# Step 140: Previous action=1, Observation=[ 0.05470112  0.39866821  0.11872589 -0.52747393], Reward=1.0
# b
# Step 141: Previous action=1, Observation=[ 0.06267449  0.59193716  0.10817641 -0.78051307], Reward=1.0
# b
# Step 142: Previous action=1, Observation=[ 0.07451323  0.78541892  0.09256615 -1.03729738], Reward=1.0
# b
# Step 143: Previous action=1, Observation=[ 0.09022161  0.9791968   0.0718202  -1.2995442 ], Reward=1.0
# b
# Step 144: Previous action=1, Observation=[ 0.10980555  1.17333736  0.04582932 -1.56890732], Reward=1.0
# b
# aa
# Step 145: Previous action=0, Observation=[ 0.13327229  0.97769914  0.01445117 -1.262289  ], Reward=1.0
# b
# Step 146: Previous action=1, Observation=[ 0.15282628  1.17263335 -0.01079461 -1.55041129], Reward=1.0
# a
# Step 147: Previous action=0, Observation=[ 0.17627894  0.97764255 -0.04180283 -1.26111568], Reward=1.0
# a
# Step 148: Previous action=0, Observation=[ 0.19583179  0.78307943 -0.06702515 -0.98181242], Reward=1.0
# a
# Step 149: Previous action=0, Observation=[ 0.21149338  0.58891658 -0.08666139 -0.71091273], Reward=1.0
# a
# Step 150: Previous action=0, Observation=[ 0.22327171  0.39509484 -0.10087965 -0.44671773], Reward=1.0
# a
# Step 151: Previous action=0, Observation=[ 0.23117361  0.20153389 -0.109814   -0.18746075], Reward=1.0
# a
# Step 152: Previous action=0, Observation=[ 0.23520429  0.0081404  -0.11356322  0.06866165], Reward=1.0
# a
# Step 153: Previous action=0, Observation=[ 0.2353671  -0.18518572 -0.11218998  0.32346704], Reward=1.0
# a
# Step 154: Previous action=0, Observation=[ 0.23166338 -0.37854627 -0.10572064  0.57876975], Reward=1.0
# a
# Step 155: Previous action=0, Observation=[ 0.22409246 -0.57204013 -0.09414525  0.83636607], Reward=1.0
# a
# Step 156: Previous action=0, Observation=[ 0.21265165 -0.76575876 -0.07741793  1.09801938], Reward=1.0
# a
# Step 157: Previous action=0, Observation=[ 0.19733648 -0.95978091 -0.05545754  1.36544274], Reward=1.0
# a
# Step 158: Previous action=0, Observation=[ 0.17814086 -1.15416627 -0.02814868  1.64027636], Reward=1.0
# a
# bb
# Step 159: Previous action=1, Observation=[ 0.15505754 -0.95872604  0.00465684  1.33895754], Reward=1.0
# b
# Step 160: Previous action=1, Observation=[ 0.13588302 -0.76366304  0.03143599  1.04773531], Reward=1.0
# b
# Step 161: Previous action=1, Observation=[ 0.12060975 -0.56897204  0.0523907   0.76508376], Reward=1.0
# b
# Step 162: Previous action=1, Observation=[ 0.10923031 -0.37460917  0.06769237  0.4893353 ], Reward=1.0
# b
# Step 163: Previous action=1, Observation=[ 0.10173813 -0.18050425  0.07747908  0.21873109], Reward=1.0
# b
# Step 164: Previous action=1, Observation=[ 0.09812805  0.01342958  0.0818537  -0.04854088], Reward=1.0
# b
# Step 165: Previous action=1, Observation=[ 0.09839664  0.20728823  0.08088288 -0.31431713], Reward=1.0
# b
# Step 166: Previous action=1, Observation=[ 0.1025424   0.40117044  0.07459654 -0.58043602], Reward=1.0
# b
# Step 167: Previous action=1, Observation=[ 0.11056581  0.59517218  0.06298782 -0.84871829], Reward=1.0
# b
# Step 168: Previous action=1, Observation=[ 0.12246925  0.78938111  0.04601346 -1.12094782], Reward=1.0
# b
# Step 169: Previous action=1, Observation=[ 0.13825688  0.98387037  0.0235945  -1.39884974], Reward=1.0
# b
# Step 170: Previous action=1, Observation=[ 0.15793428  1.17869117 -0.0043825  -1.68406347], Reward=1.0
# a
# Step 171: Previous action=0, Observation=[ 0.18150811  0.98362022 -0.03806376 -1.3927483 ], Reward=1.0
# a
# Step 172: Previous action=0, Observation=[ 0.20118051  0.78899224 -0.06591873 -1.11220584], Reward=1.0
# a
# Step 173: Previous action=0, Observation=[ 0.21696036  0.59479508 -0.08816285 -0.84090883], Reward=1.0
# a
# Step 174: Previous action=0, Observation=[ 0.22885626  0.40098017 -0.10498102 -0.5772019 ], Reward=1.0
# a
# Step 175: Previous action=0, Observation=[ 0.23687586  0.20747418 -0.11652506 -0.31934867], Reward=1.0
# a
# Step 176: Previous action=0, Observation=[ 0.24102534  0.01418788 -0.12291204 -0.06556623], Reward=1.0
# a
# Step 177: Previous action=0, Observation=[ 0.2413091  -0.17897709 -0.12422336  0.1859501 ], Reward=1.0
# a
# Step 178: Previous action=0, Observation=[ 0.23772956 -0.37212298 -0.12050436  0.43700861], Reward=1.0
# a
# Step 179: Previous action=0, Observation=[ 0.2302871  -0.56535148 -0.11176419  0.68940686], Reward=1.0
# a
# Step 180: Previous action=0, Observation=[ 0.21898007 -0.75875956 -0.09797605  0.94491863], Reward=1.0
# a
# Step 181: Previous action=0, Observation=[ 0.20380488 -0.95243498 -0.07907768  1.20527961], Reward=1.0
# a
# Step 182: Previous action=0, Observation=[ 0.18475618 -1.14645093 -0.05497208  1.47216947], Reward=1.0
# a
# Step 183: Previous action=0, Observation=[ 0.16182716 -1.34085932 -0.02552869  1.7471879 ], Reward=1.0
# a
# bb
# Step 184: Previous action=1, Observation=[ 0.13500998 -1.14545675  0.00941506  1.44667492], Reward=1.0
# b
# Step 185: Previous action=1, Observation=[ 0.11210084 -0.95045186  0.03834856  1.15694854], Reward=1.0
# b
# Step 186: Previous action=1, Observation=[ 0.0930918  -0.7558502   0.06148753  0.87653238], Reward=1.0
# b
# Step 187: Previous action=1, Observation=[ 0.0779748  -0.56161546  0.07901818  0.6037968 ], Reward=1.0
# b
# Step 188: Previous action=1, Observation=[ 0.06674249 -0.36768237  0.09109412  0.33701205], Reward=1.0
# b
# Step 189: Previous action=1, Observation=[ 0.05938884 -0.17396685  0.09783436  0.07438817], Reward=1.0
# b
# Step 190: Previous action=1, Observation=[ 0.05590951  0.01962633  0.09932212 -0.18589552], Reward=1.0
# b
# Step 191: Previous action=1, Observation=[ 0.05630203  0.21319728  0.09560421 -0.44566824], Reward=1.0
# b
# Step 192: Previous action=1, Observation=[ 0.06056598  0.40684585  0.08669085 -0.70674978], Reward=1.0
# b
# Step 193: Previous action=1, Observation=[ 0.06870289  0.60066663  0.07255585 -0.97093396], Reward=1.0
# b
# Step 194: Previous action=1, Observation=[ 0.08071623  0.79474371  0.05313717 -1.23997095], Reward=1.0
# b
# Step 195: Previous action=1, Observation=[ 0.0966111   0.98914458  0.02833775 -1.51554569], Reward=1.0
# b
# aa
# Step 196: Previous action=0, Observation=[ 0.11639399  0.79369141 -0.00197316 -1.21415347], Reward=1.0
# a
# Step 197: Previous action=0, Observation=[ 0.13226782  0.59859498 -0.02625623 -0.92208949], Reward=1.0
# a
# Step 198: Previous action=0, Observation=[ 0.14423972  0.40383745 -0.04469802 -0.63777234], Reward=1.0
# a
# Step 199: Previous action=0, Observation=[ 0.15231647  0.20936636 -0.05745347 -0.3594939 ], Reward=1.0
# a
# Step 200: Previous action=0, Observation=[ 0.1565038   0.01510619 -0.06464335 -0.08546647], Reward=1.0
# a
# Step 201: Previous action=0, Observation=[ 0.15680592 -0.17903244 -0.06635268  0.18614134], Reward=1.0
# a
# Step 202: Previous action=0, Observation=[ 0.15322527 -0.37314539 -0.06262985  0.45717666], Reward=1.0
# a
# Step 203: Previous action=0, Observation=[ 0.14576236 -0.56732859 -0.05348632  0.72947924], Reward=1.0
# a
# Step 204: Previous action=0, Observation=[ 0.13441579 -0.76167204 -0.03889673  1.00486005], Reward=1.0
# a
# Step 205: Previous action=0, Observation=[ 0.11918235 -0.9562535  -0.01879953  1.28507871], Reward=1.0
# a
# Step 206: Previous action=0, Observation=[ 0.10005728 -1.15113115  0.00690204  1.5718168 ], Reward=1.0
# b
# Step 207: Previous action=1, Observation=[ 0.07703466 -0.95609222  0.03833838  1.28129456], Reward=1.0
# b
# Step 208: Previous action=1, Observation=[ 0.05791281 -0.76147909  0.06396427  1.0008581 ], Reward=1.0
# b
# Step 209: Previous action=1, Observation=[ 0.04268323 -0.56726757  0.08398143  0.72892925], Reward=1.0
# b
# Step 210: Previous action=1, Observation=[ 0.03133788 -0.37340071  0.09856002  0.46381537], Reward=1.0
# b
# Step 211: Previous action=1, Observation=[ 0.02386987 -0.17979963  0.10783633  0.20375286], Reward=1.0
# b
# Step 212: Previous action=1, Observation=[ 0.02027387  0.01362816  0.11191138 -0.05306102], Reward=1.0
# b
# Step 213: Previous action=1, Observation=[ 0.02054644  0.20698236  0.11085016 -0.3084447 ], Reward=1.0
# b
# Step 214: Previous action=1, Observation=[ 0.02468608  0.40036466  0.10468127 -0.56421455], Reward=1.0
# b
# Step 215: Previous action=1, Observation=[ 0.03269338  0.59387413  0.09339698 -0.82216971], Reward=1.0
# b
# Step 216: Previous action=1, Observation=[ 0.04457086  0.78760262  0.07695358 -1.08407714], Reward=1.0
# b
# Step 217: Previous action=1, Observation=[ 0.06032291  0.98162953  0.05527204 -1.35165415], Reward=1.0
# b
# Step 218: Previous action=1, Observation=[ 0.0799555   1.17601547  0.02823896 -1.62654608], Reward=1.0
# b
# aa
# Step 219: Previous action=0, Observation=[ 0.10347581  0.98057303 -0.00429196 -1.32519815], Reward=1.0
# a
# Step 220: Previous action=0, Observation=[ 0.12308727  0.78550554 -0.03079593 -1.03386144], Reward=1.0
# a
# Step 221: Previous action=0, Observation=[ 0.13879738  0.59080637 -0.05147316 -0.75100373], Reward=1.0
# a
# Step 222: Previous action=0, Observation=[ 0.15061351  0.39643065 -0.06649323 -0.47495275], Reward=1.0
# a
# Step 223: Previous action=0, Observation=[ 0.15854212  0.20230759 -0.07599229 -0.20394624], Reward=1.0
# a
# Step 224: Previous action=0, Observation=[ 0.16258828  0.00835    -0.08007121  0.06383026], Reward=1.0
# a
# Step 225: Previous action=0, Observation=[ 0.16275528 -0.18553807 -0.0787946   0.33021475], Reward=1.0
# a
# Step 226: Previous action=0, Observation=[ 0.15904452 -0.37945512 -0.07219031  0.59704618], Reward=1.0
# a
# Step 227: Previous action=0, Observation=[ 0.15145541 -0.57349657 -0.06024939  0.86614474], Reward=1.0
# a
# Step 228: Previous action=0, Observation=[ 0.13998548 -0.76774908 -0.04292649  1.13929221], Reward=1.0
# a
# Step 229: Previous action=0, Observation=[ 0.1246305  -0.96228429 -0.02014065  1.4182097 ], Reward=1.0
# a
# Step 230: Previous action=0, Observation=[ 0.10538481 -1.15715121  0.00822355  1.70452985], Reward=1.0
# b
# Step 231: Previous action=1, Observation=[ 0.08224179 -0.96212485  0.04231414  1.41441789], Reward=1.0
# b
# Step 232: Previous action=1, Observation=[ 0.06299929 -0.76755193  0.0706025   1.13525641], Reward=1.0
# b
# Step 233: Previous action=1, Observation=[ 0.04764825 -0.57342115  0.09330763  0.86552559], Reward=1.0
# b
# Step 234: Previous action=1, Observation=[ 0.03617983 -0.37968458  0.11061814  0.60357752], Reward=1.0
# b
# Step 235: Previous action=1, Observation=[ 0.02858614 -0.18626937  0.12268969  0.34768339], Reward=1.0
# b
# Step 236: Previous action=1, Observation=[0.02486075 0.00691335 0.12964336 0.09606785], Reward=1.0
# b
# Step 237: Previous action=1, Observation=[ 0.02499902  0.19996187  0.13156472 -0.15306638], Reward=1.0
# b
# Step 238: Previous action=1, Observation=[ 0.02899826  0.39297863  0.12850339 -0.40152086], Reward=1.0
# b
# Step 239: Previous action=1, Observation=[ 0.03685783  0.58606601  0.12047297 -0.65108776], Reward=1.0
# b
# Step 240: Previous action=1, Observation=[ 0.04857915  0.77932234  0.10745122 -0.9035377 ], Reward=1.0
# b
# Step 241: Previous action=1, Observation=[ 0.0641656   0.97283768  0.08938046 -1.1606067 ], Reward=1.0
# b
# Step 242: Previous action=1, Observation=[ 0.08362235  1.16668888  0.06616833 -1.42397992], Reward=1.0
# b
# Step 243: Previous action=1, Observation=[ 0.10695613  1.36093332  0.03768873 -1.69526967], Reward=1.0
# b
# aa
# Step 244: Previous action=0, Observation=[ 0.13417479  1.16539733  0.00378334 -1.39109611], Reward=1.0
# b
# Step 245: Previous action=1, Observation=[ 0.15748274  1.36047196 -0.02403859 -1.68259366], Reward=1.0
# a
# Step 246: Previous action=0, Observation=[ 0.18469218  1.16563647 -0.05769046 -1.39749153], Reward=1.0
# a
# Step 247: Previous action=0, Observation=[ 0.20800491  0.97127747 -0.08564029 -1.12338963], Reward=1.0
# a
# Step 248: Previous action=0, Observation=[ 0.22743046  0.77737622 -0.10810808 -0.85875117], Reward=1.0
# a
# Step 249: Previous action=0, Observation=[ 0.24297798  0.58387985 -0.1252831  -0.60192295], Reward=1.0
# a
# Step 250: Previous action=0, Observation=[ 0.25465558  0.39071242 -0.13732156 -0.35117974], Reward=1.0
# a
# Step 251: Previous action=0, Observation=[ 0.26246983  0.19778326 -0.14434516 -0.10475606], Reward=1.0
# a
# Step 252: Previous action=0, Observation=[ 0.26642549  0.00499313 -0.14644028  0.13913142], Reward=1.0
# a
# Step 253: Previous action=0, Observation=[ 0.26652536 -0.187761   -0.14365765  0.38226826], Reward=1.0
# a
# Step 254: Previous action=0, Observation=[ 0.26277014 -0.38058216 -0.13601229  0.62643038], Reward=1.0
# a
# Step 255: Previous action=0, Observation=[ 0.25515849 -0.57356975 -0.12348368  0.87337385], Reward=1.0
# a
# Step 256: Previous action=0, Observation=[ 0.2436871  -0.76681586 -0.1060162   1.12482381], Reward=1.0
# a
# Step 257: Previous action=0, Observation=[ 0.22835078 -0.96040076 -0.08351973  1.38246044], Reward=1.0
# a
# Step 258: Previous action=0, Observation=[ 0.20914277 -1.15438724 -0.05587052  1.64789963], Reward=1.0
# a
# bb
# Step 259: Previous action=1, Observation=[ 0.18605502 -0.95865829 -0.02291252  1.33834693], Reward=1.0
# a
# Step 260: Previous action=0, Observation=[ 0.16688185 -1.15348431  0.00385441  1.62377356], Reward=1.0
# b
# Step 261: Previous action=1, Observation=[ 0.14381217 -0.95840794  0.03632989  1.33229436], Reward=1.0
# b
# Step 262: Previous action=1, Observation=[ 0.12464401 -0.76376244  0.06297577  1.05119741], Reward=1.0
# b
# Step 263: Previous action=1, Observation=[ 0.10936876 -0.56952971  0.08399972  0.77892851], Reward=1.0
# b
# Step 264: Previous action=1, Observation=[ 0.09797817 -0.37565698  0.09957829  0.51381166], Reward=1.0
# b
# Step 265: Previous action=1, Observation=[ 0.09046503 -0.18206809  0.10985452  0.25409449], Reward=1.0
# b
# Step 266: Previous action=1, Observation=[ 0.08682367  0.01132785  0.11493641 -0.00201844], Reward=1.0
# b
# Step 267: Previous action=1, Observation=[ 0.08705022  0.20462989  0.11489605 -0.25634146], Reward=1.0
# b
# Step 268: Previous action=1, Observation=[ 0.09114282  0.39793998  0.10976922 -0.5106896 ], Reward=1.0
# b
# Step 269: Previous action=1, Observation=[ 0.09910162  0.59135832  0.09955542 -0.76686358], Reward=1.0
# b
# Step 270: Previous action=1, Observation=[ 0.11092879  0.78497899  0.08421815 -1.02663552], Reward=1.0
# b
# Step 271: Previous action=1, Observation=[ 0.12662837  0.97888493  0.06368544 -1.29173268], Reward=1.0
# b
# Step 272: Previous action=1, Observation=[ 0.14620606  1.17314204  0.03785079 -1.56381677], Reward=1.0
# b
# aa
# Step 273: Previous action=0, Observation=[ 0.16966891  0.97758855  0.00657445 -1.25957116], Reward=1.0
# b
# Step 274: Previous action=1, Observation=[ 0.18922068  1.17262577 -0.01861697 -1.5501878 ], Reward=1.0
# a
# Step 275: Previous action=0, Observation=[ 0.21267319  0.97773205 -0.04962073 -1.26337095], Reward=1.0
# a
# Step 276: Previous action=0, Observation=[ 0.23222783  0.78327834 -0.07488814 -0.9866319 ], Reward=1.0
# a
# Step 277: Previous action=0, Observation=[ 0.2478934   0.5892348  -0.09462078 -0.71837894], Reward=1.0
# a
# Step 278: Previous action=0, Observation=[ 0.2596781   0.39554071 -0.10898836 -0.45691447], Reward=1.0
# a
# Step 279: Previous action=0, Observation=[ 0.26758891  0.20211476 -0.11812665 -0.20047622], Reward=1.0
# a
# Step 280: Previous action=0, Observation=[ 0.2716312   0.00886298 -0.12213618  0.05273281], Reward=1.0
# a
# Step 281: Previous action=0, Observation=[ 0.27180846 -0.18431525 -0.12108152  0.30452275], Reward=1.0
# a
# Step 282: Previous action=0, Observation=[ 0.26812216 -0.37752232 -0.11499106  0.55670048], Reward=1.0
# a
# Step 283: Previous action=0, Observation=[ 0.26057171 -0.57085808 -0.10385705  0.81105597], Reward=1.0
# a
# Step 284: Previous action=0, Observation=[ 0.24915455 -0.76441558 -0.08763594  1.06934868], Reward=1.0
# a
# Step 285: Previous action=0, Observation=[ 0.23386624 -0.95827611 -0.06624896  1.33329154], Reward=1.0
# a
# Step 286: Previous action=0, Observation=[ 0.21470072 -1.15250326 -0.03958313  1.60453022], Reward=1.0
# a
# bb
# Step 287: Previous action=1, Observation=[ 0.19165065 -0.95693602 -0.00749253  1.29977475], Reward=1.0
# a
# Step 288: Previous action=0, Observation=[ 0.17251193 -1.15196207  0.01850297  1.59010283], Reward=1.0
# b
# Step 289: Previous action=1, Observation=[ 0.14947269 -0.95706466  0.05030503  1.30324632], Reward=1.0
# b
# Step 290: Previous action=1, Observation=[ 0.1303314  -0.7626156   0.07636995  1.02672514], Reward=1.0
# b
# Step 291: Previous action=1, Observation=[ 0.11507909 -0.56858882  0.09690445  0.75896424], Reward=1.0
# b
# Step 292: Previous action=1, Observation=[ 0.10370731 -0.37492622  0.11208374  0.49827854], Reward=1.0
# b
# Step 293: Previous action=1, Observation=[ 0.09620878 -0.1815482   0.12204931  0.24291531], Reward=1.0
# b
# Step 294: Previous action=1, Observation=[ 0.09257782  0.0116382   0.12690762 -0.00891522], Reward=1.0
# b
# Step 295: Previous action=1, Observation=[ 0.09281058  0.20473326  0.12672931 -0.25901775], Reward=1.0
# b
# Step 296: Previous action=1, Observation=[ 0.09690525  0.39783969  0.12154896 -0.50919571], Reward=1.0
# b
# Step 297: Previous action=1, Observation=[ 0.10486204  0.59105839  0.11136504 -0.76123795], Reward=1.0
# b
# Step 298: Previous action=1, Observation=[ 0.11668321  0.7844844   0.09614028 -1.01690596], Reward=1.0
# b
# Step 299: Previous action=1, Observation=[ 0.1323729   0.97820227  0.07580216 -1.27791919], Reward=1.0
# b
# Step 300: Previous action=1, Observation=[ 0.15193694  1.17228048  0.05024378 -1.54593603], Reward=1.0
# b
# aa
# Step 301: Previous action=0, Observation=[ 0.17538255  0.97659239  0.01932506 -1.23800886], Reward=1.0
# b
# Step 302: Previous action=1, Observation=[ 0.1949144   1.17146083 -0.00543512 -1.52457573], Reward=1.0
# a
# Step 303: Previous action=0, Observation=[ 0.21834362  0.97640492 -0.03592663 -1.2335941 ], Reward=1.0
# a
# Step 304: Previous action=0, Observation=[ 0.23787172  0.78176282 -0.06059851 -0.9523795 ], Reward=1.0
# a
# Step 305: Previous action=0, Observation=[ 0.25350697  0.58750635 -0.0796461  -0.67933471], Reward=1.0
# a
# Step 306: Previous action=0, Observation=[ 0.2652571   0.39357582 -0.0932328  -0.41275228], Reward=1.0
# a
# Step 307: Previous action=0, Observation=[ 0.27312862  0.19989059 -0.10148784 -0.15085695], Reward=1.0
# a
# Step 308: Previous action=0, Observation=[ 0.27712643  0.00635725 -0.10450498  0.10816308], Reward=1.0
# a
# Step 309: Previous action=0, Observation=[ 0.27725357 -0.18712397 -0.10234172  0.36613299], Reward=1.0
# a
# Step 310: Previous action=0, Observation=[ 0.27351109 -0.38065398 -0.09501906  0.62487311], Reward=1.0
# a
# Step 311: Previous action=0, Observation=[ 0.26589801 -0.57432999 -0.0825216   0.88618305], Reward=1.0
# a
# Step 312: Previous action=0, Observation=[ 0.25441142 -0.76824057 -0.06479794  1.1518253 ], Reward=1.0
# a
# Step 313: Previous action=0, Observation=[ 0.2390466  -0.96246005 -0.04176143  1.42350585], Reward=1.0
# a
# Step 314: Previous action=0, Observation=[ 0.2197974  -1.1570415  -0.01329132  1.70284925], Reward=1.0
# a
# bb
# Step 315: Previous action=1, Observation=[ 0.19665657 -0.96176908  0.02076567  1.40605896], Reward=1.0
# b
# Step 316: Previous action=1, Observation=[ 0.17742119 -0.76691095  0.04888685  1.11993945], Reward=1.0
# b
# Step 317: Previous action=1, Observation=[ 0.16208297 -0.57246317  0.07128564  0.84298326], Reward=1.0
# b
# Step 318: Previous action=1, Observation=[ 0.15063371 -0.37838276  0.0881453   0.57354225], Reward=1.0
# b
# Step 319: Previous action=1, Observation=[ 0.14306605 -0.18460003  0.09961615  0.30987781], Reward=1.0
# b
# Step 320: Previous action=1, Observation=[0.13937405 0.00897194 0.1058137  0.05019807], Reward=1.0
# b
# Step 321: Previous action=1, Observation=[ 0.13955349  0.20243002  0.10681767 -0.20731483], Reward=1.0
# b
# Step 322: Previous action=1, Observation=[ 0.14360209  0.39587526  0.10267137 -0.46448414], Reward=1.0
# b
# Step 323: Previous action=1, Observation=[ 0.1515196   0.5894079   0.09338169 -0.72312198], Reward=1.0
# b
# Step 324: Previous action=1, Observation=[ 0.16330776  0.78312272  0.07891925 -0.98501389], Reward=1.0
# b
# Step 325: Previous action=1, Observation=[ 0.17897021  0.97710396  0.05921897 -1.2519019 ], Reward=1.0
# b
# Step 326: Previous action=1, Observation=[ 0.19851229  1.1714193   0.03418093 -1.52546378], Reward=1.0
# b
# aa
# Step 327: Previous action=0, Observation=[ 0.22194067  0.97590182  0.00367166 -1.22231163], Reward=1.0
# b
# Step 328: Previous action=1, Observation=[ 0.24145871  1.17097627 -0.02077458 -1.51384187], Reward=1.0
# a
# Step 329: Previous action=0, Observation=[ 0.26487824  0.97611188 -0.05105141 -1.22771564], Reward=1.0
# a
# Step 330: Previous action=0, Observation=[ 0.28440047  0.78168281 -0.07560573 -0.95145461], Reward=1.0
# a
# Step 331: Previous action=0, Observation=[ 0.30003413  0.58765532 -0.09463482 -0.68345172], Reward=1.0
# a
# Step 332: Previous action=0, Observation=[ 0.31178724  0.39396597 -0.10830385 -0.42199882], Reward=1.0
# a
# Step 333: Previous action=0, Observation=[ 0.31966656  0.20053173 -0.11674383 -0.16532661], Reward=1.0
# a
# Step 334: Previous action=0, Observation=[ 0.32367719  0.00725764 -0.12005036  0.08836636], Reward=1.0
# a
# Step 335: Previous action=0, Observation=[ 0.32382234 -0.18595724 -0.11828303  0.34089264], Reward=1.0
# a
# Step 336: Previous action=0, Observation=[ 0.3201032  -0.37921508 -0.11146518  0.59405969], Reward=1.0
# a
# Step 337: Previous action=0, Observation=[ 0.3125189  -0.57261486 -0.09958399  0.84965612], Reward=1.0
# a
# Step 338: Previous action=0, Observation=[ 0.3010666  -0.76624804 -0.08259087  1.10943755], Reward=1.0
# a
# Step 339: Previous action=0, Observation=[ 0.28574164 -0.96019338 -0.06040211  1.3751098 ], Reward=1.0
# a
# Step 340: Previous action=0, Observation=[ 0.26653777 -1.15451073 -0.03289992  1.64830685], Reward=1.0
# a
# bb
# Step 341: Previous action=1, Observation=[ 2.43447557e-01 -9.59019956e-01  6.62179425e-05  1.34555854e+00], Reward=1.0
# b
# Step 342: Previous action=1, Observation=[ 0.22426716 -0.76389884  0.02697739  1.05289633], Reward=1.0
# b
# Step 343: Previous action=1, Observation=[ 0.20898918 -0.56914479  0.04803532  0.76880195], Reward=1.0
# b
# Step 344: Previous action=1, Observation=[ 0.19760629 -0.37471579  0.06341135  0.4916118 ], Reward=1.0
# b
# Step 345: Previous action=1, Observation=[ 0.19011197 -0.18054292  0.07324359  0.21956833], Reward=1.0
# b
# Step 346: Previous action=1, Observation=[ 0.18650111  0.01345979  0.07763496 -0.04914115], Reward=1.0
# b
# Step 347: Previous action=1, Observation=[ 0.18677031  0.20738764  0.07665213 -0.31635498], Reward=1.0
# b
# Step 348: Previous action=1, Observation=[ 0.19091806  0.40133884  0.07032503 -0.58391387], Reward=1.0
# b
# Step 349: Previous action=1, Observation=[ 0.19894484  0.59540881  0.05864676 -0.85364075], Reward=1.0
# b
# Step 350: Previous action=1, Observation=[ 0.21085301  0.78968444  0.04157394 -1.12732092], Reward=1.0
# b
# Step 351: Previous action=1, Observation=[ 0.2266467   0.98423779  0.01902752 -1.40667957], Reward=1.0
# b
# Step 352: Previous action=1, Observation=[ 0.24633146  1.17911849 -0.00910607 -1.69335395], Reward=1.0
# a
# Step 353: Previous action=0, Observation=[ 0.26991383  0.98410284 -0.04297315 -1.40351974], Reward=1.0
# a
# Step 354: Previous action=0, Observation=[ 0.28959588  0.78954014 -0.07104354 -1.12457534], Reward=1.0
# a
# Step 355: Previous action=0, Observation=[ 0.30538669  0.59541762 -0.09353505 -0.85499532], Reward=1.0
# a
# Step 356: Previous action=0, Observation=[ 0.31729504  0.40168633 -0.11063495 -0.59312788], Reward=1.0
# a
# Step 357: Previous action=0, Observation=[ 0.32532877  0.20827276 -0.12249751 -0.33724161], Reward=1.0
# a
# Step 358: Previous action=0, Observation=[ 0.32949422  0.01508757 -0.12924234 -0.08555954], Reward=1.0
# a
# Step 359: Previous action=0, Observation=[ 0.32979597 -0.1779677  -0.13095354  0.16371665], Reward=1.0
# a
# Step 360: Previous action=0, Observation=[ 0.32623662 -0.37099557 -0.1276792   0.41238895], Reward=1.0
# a
# Step 361: Previous action=0, Observation=[ 0.31881671 -0.56409829 -0.11943142  0.66224949], Reward=1.0
# a
# Step 362: Previous action=0, Observation=[ 0.30753474 -0.75737388 -0.10618643  0.91506826], Reward=1.0
# a
# Step 363: Previous action=0, Observation=[ 0.29238726 -0.95091189 -0.08788507  1.17257995], Reward=1.0
# a
# Step 364: Previous action=0, Observation=[ 0.27336903 -1.14478837 -0.06443347  1.43646733], Reward=1.0
# a
# Step 365: Previous action=0, Observation=[ 0.25047326 -1.33905949 -0.03570412  1.70833898], Reward=1.0
# a
# bb
# Step 366: Previous action=1, Observation=[ 0.22369207 -1.14354579 -0.00153734  1.40476056], Reward=1.0
# a
# Step 367: Previous action=0, Observation=[ 0.20082115 -1.33864862  0.02655787  1.69696248], Reward=1.0
# b
# Step 368: Previous action=1, Observation=[ 0.17404818 -1.14384282  0.06049712  1.41266391], Reward=1.0
# b
# Step 369: Previous action=1, Observation=[ 0.15117132 -0.94952063  0.0887504   1.13948917], Reward=1.0
# b
# Step 370: Previous action=1, Observation=[ 0.13218091 -0.75566397  0.11154018  0.87590701], Reward=1.0
# b
# Step 371: Previous action=1, Observation=[ 0.11706763 -0.56222049  0.12905832  0.62026978], Reward=1.0
# b
# Step 372: Previous action=1, Observation=[ 0.10582322 -0.36911467  0.14146371  0.3708579 ], Reward=1.0
# b
# Step 373: Previous action=1, Observation=[ 0.09844093 -0.17625616  0.14888087  0.12591167], Reward=1.0
# b
# Step 374: Previous action=1, Observation=[ 0.09491581  0.01645408  0.15139911 -0.1163465 ], Reward=1.0
# b
# Step 375: Previous action=1, Observation=[ 0.09524489  0.20911909  0.14907218 -0.3576967 ], Reward=1.0
# b
# Step 376: Previous action=1, Observation=[ 0.09942727  0.40184214  0.14191824 -0.59991005], Reward=1.0
# b
# Step 377: Previous action=1, Observation=[ 0.10746411  0.59472331  0.12992004 -0.84473906], Reward=1.0
# b
# Step 378: Previous action=1, Observation=[ 0.11935858  0.78785591  0.11302526 -1.09390733], Reward=1.0
# b
# Step 379: Previous action=1, Observation=[ 0.1351157   0.98132228  0.09114711 -1.34909653], Reward=1.0
# b
# Step 380: Previous action=1, Observation=[ 0.15474214  1.17518838  0.06416518 -1.6119284 ], Reward=1.0
# b
# aa
# Step 381: Previous action=0, Observation=[ 0.17824591  0.97937018  0.03192662 -1.29995394], Reward=1.0
# b
# Step 382: Previous action=1, Observation=[ 0.19783331  1.17407268  0.00592754 -1.58247402], Reward=1.0
# b
# aa
# Step 383: Previous action=0, Observation=[ 0.22131477  0.97888071 -0.02572194 -1.28794852], Reward=1.0
# a
# Step 384: Previous action=0, Observation=[ 0.24089238  0.78409529 -0.05148091 -1.00342846], Reward=1.0
# a
# Step 385: Previous action=0, Observation=[ 0.25657429  0.58969746 -0.07154948 -0.72734674], Reward=1.0
# a
# Step 386: Previous action=0, Observation=[ 0.26836824  0.39563381 -0.08609642 -0.45801366], Reward=1.0
# a
# Step 387: Previous action=0, Observation=[ 0.27628091  0.20182777 -0.09525669 -0.19366248], Reward=1.0
# a
# Step 388: Previous action=0, Observation=[ 0.28031747  0.00818839 -0.09912994  0.06751667], Reward=1.0
# a
# Step 389: Previous action=0, Observation=[ 0.28048124 -0.1853829  -0.09777961  0.32735165], Reward=1.0
# a
# Step 390: Previous action=0, Observation=[ 0.27677358 -0.37898667 -0.09123257  0.58766872], Reward=1.0
# a
# Step 391: Previous action=0, Observation=[ 0.26919384 -0.57272049 -0.0794792   0.85027572], Reward=1.0
# a
# Step 392: Previous action=0, Observation=[ 0.25773943 -0.76667393 -0.06247369  1.11694518], Reward=1.0
# a
# Step 393: Previous action=0, Observation=[ 0.24240596 -0.96092283 -0.04013478  1.38939479], Reward=1.0
# a
# Step 394: Previous action=0, Observation=[ 0.2231875  -1.15552246 -0.01234689  1.6692627 ], Reward=1.0
# a
# bb
# Step 395: Previous action=1, Observation=[ 0.20007705 -0.96025919  0.02103837  1.37276024], Reward=1.0
# b
# Step 396: Previous action=1, Observation=[ 0.18087187 -0.76540651  0.04849357  1.08673071], Reward=1.0
# b
# Step 397: Previous action=1, Observation=[ 0.16556374 -0.57095652  0.07022819  0.80965014], Reward=1.0
# b
# Step 398: Previous action=1, Observation=[ 0.15414461 -0.37686348  0.08642119  0.53985836], Reward=1.0
# b
# Step 399: Previous action=1, Observation=[ 0.14660734 -0.18305588  0.09721836  0.27560811], Reward=1.0
# b
# Step 400: Previous action=1, Observation=[0.14294622 0.0105543  0.10273052 0.01510136], Reward=1.0
# b
# Step 401: Previous action=1, Observation=[ 0.1431573   0.20406441  0.10303255 -0.24348381], Reward=1.0
# b
# Step 402: Previous action=1, Observation=[ 0.14723859  0.39757533  0.09816287 -0.50197285], Reward=1.0
# b
# Step 403: Previous action=1, Observation=[ 0.1551901   0.59118653  0.08812341 -0.76217799], Reward=1.0
# b
# Step 404: Previous action=1, Observation=[ 0.16701383  0.78499123  0.07287985 -1.02588224], Reward=1.0
# b
# Step 405: Previous action=1, Observation=[ 0.18271365  0.97907115  0.05236221 -1.2948216 ], Reward=1.0
# b
# Step 406: Previous action=1, Observation=[ 0.20229508  1.17349016  0.02646578 -1.57066296], Reward=1.0
# b
# aa
# Step 407: Previous action=0, Observation=[ 0.22576488  0.97806253 -0.00494748 -1.26984415], Reward=1.0
# a
# Step 408: Previous action=0, Observation=[ 0.24532613  0.7830041  -0.03034437 -0.97871464], Reward=1.0
# a
# Step 409: Previous action=0, Observation=[ 0.26098621  0.58830182 -0.04991866 -0.69571555], Reward=1.0
# a
# Step 410: Previous action=0, Observation=[ 0.27275225  0.39390644 -0.06383297 -0.4191557 ], Reward=1.0
# a
# Step 411: Previous action=0, Observation=[ 0.28063038  0.19974434 -0.07221608 -0.14725985], Reward=1.0
# a
# Step 412: Previous action=0, Observation=[ 0.28462526  0.00572686 -0.07516128  0.12179475], Reward=1.0
# a
# Step 413: Previous action=0, Observation=[ 0.2847398  -0.18824228 -0.07272539  0.3898504 ], Reward=1.0
# a
# Step 414: Previous action=0, Observation=[ 0.28097496 -0.38226074 -0.06492838  0.65874639], Reward=1.0
# a
# Step 415: Previous action=0, Observation=[ 0.27332974 -0.5764218  -0.05175345  0.93029876], Reward=1.0
# a
# Step 416: Previous action=0, Observation=[ 0.26180131 -0.77080847 -0.03314747  1.20627965], Reward=1.0
# a
# Step 417: Previous action=0, Observation=[ 0.24638514 -0.96548679 -0.00902188  1.48839314], Reward=1.0
# a
# Step 418: Previous action=0, Observation=[ 0.2270754  -1.1604977   0.02074598  1.7782452 ], Reward=1.0
# b
# Step 419: Previous action=1, Observation=[ 0.20386545 -0.96561533  0.05631088  1.49208343], Reward=1.0
# b
# Step 420: Previous action=1, Observation=[ 0.18455314 -0.77122207  0.08615255  1.21750237], Reward=1.0
# b
# Step 421: Previous action=1, Observation=[ 0.1691287  -0.57731018  0.1105026   0.95301085], Reward=1.0
# b
# Step 422: Previous action=1, Observation=[ 0.15758249 -0.38383458  0.12956282  0.6969892 ], Reward=1.0
# b
# Step 423: Previous action=1, Observation=[ 0.1499058  -0.19072466  0.1435026   0.44773714], Reward=1.0
# b
# Step 424: Previous action=1, Observation=[0.14609131 0.0021068  0.15245734 0.2035082 ], Reward=1.0
# b
# Step 425: Previous action=1, Observation=[ 0.14613345  0.19475703  0.15652751 -0.03746626], Reward=1.0
# b
# Step 426: Previous action=1, Observation=[ 0.15002859  0.38732843  0.15577818 -0.27696055], Reward=1.0
# b
# Step 427: Previous action=1, Observation=[ 0.15777516  0.57992465  0.15023897 -0.51674291], Reward=1.0
# b
# Step 428: Previous action=1, Observation=[ 0.16937365  0.77264731  0.13990411 -0.75856619], Reward=1.0
# b
# Step 429: Previous action=1, Observation=[ 0.18482659  0.96559266  0.12473279 -1.00415866], Reward=1.0
# b
# Step 430: Previous action=1, Observation=[ 0.20413845  1.15884778  0.10464962 -1.2552128 ], Reward=1.0
# b
# Step 431: Previous action=1, Observation=[ 0.2273154   1.3524858   0.07954536 -1.51336995], Reward=1.0
# b
# aa
# Step 432: Previous action=0, Observation=[ 0.25436512  1.15649596  0.04927796 -1.1969531 ], Reward=1.0
# b
# Step 433: Previous action=1, Observation=[ 0.27749504  1.35094666  0.0253389  -1.47379323], Reward=1.0
# b
# Step 434: Previous action=1, Observation=[ 0.30451397  1.54574991 -0.00413696 -1.75845547], Reward=1.0
# a
# Step 435: Previous action=0, Observation=[ 0.33542897  1.35067506 -0.03930607 -1.46706195], Reward=1.0
# a
# Step 436: Previous action=0, Observation=[ 0.36244247  1.15605571 -0.06864731 -1.18691142], Reward=1.0
# a
# Step 437: Previous action=0, Observation=[ 0.38556359  0.96188774 -0.09238554 -0.91651192], Reward=1.0
# a
# Step 438: Previous action=0, Observation=[ 0.40480134  0.76812827 -0.11071578 -0.65423487], Reward=1.0
# a
# Step 439: Previous action=0, Observation=[ 0.42016391  0.57470784 -0.12380048 -0.39836459], Reward=1.0
# a
# Step 440: Previous action=0, Observation=[ 0.43165806  0.38153969 -0.13176777 -0.14713442], Reward=1.0
# a
# Step 441: Previous action=0, Observation=[ 0.43928886  0.1885267  -0.13471046  0.10124755], Reward=1.0
# a
# Step 442: Previous action=0, Observation=[ 0.44305939 -0.00443327 -0.13268551  0.34858005], Reward=1.0
# a
# Step 443: Previous action=0, Observation=[ 0.44297072 -0.19744307 -0.1257139   0.5966548 ], Reward=1.0
# a
# Step 444: Previous action=0, Observation=[ 0.43902186 -0.39060239 -0.11378081  0.84724467], Reward=1.0
# a
# Step 445: Previous action=0, Observation=[ 0.43120982 -0.5840037  -0.09683592  1.10209139], Reward=1.0
# a
# Step 446: Previous action=0, Observation=[ 0.41952974 -0.77772761 -0.07479409  1.3628906 ], Reward=1.0
# a
# Step 447: Previous action=0, Observation=[ 0.40397519 -0.97183701 -0.04753628  1.6312717 ], Reward=1.0
# a
# bb
# Step 448: Previous action=1, Observation=[ 0.38453845 -0.77619004 -0.01491084  1.32416235], Reward=1.0
# a
# Step 449: Previous action=0, Observation=[ 0.36901465 -0.97112051  0.0115724   1.61214193], Reward=1.0
# b
# Step 450: Previous action=1, Observation=[ 0.34959224 -0.77613708  0.04381524  1.32308858], Reward=1.0
# b
# Step 451: Previous action=1, Observation=[ 0.3340695  -0.5815952   0.07027702  1.04443338], Reward=1.0
# b
# Step 452: Previous action=1, Observation=[ 0.32243759 -0.38747312  0.09116568  0.77461346], Reward=1.0
# b
# Step 453: Previous action=1, Observation=[ 0.31468813 -0.19371559  0.10665795  0.5119497 ], Reward=1.0
# b
# Step 454: Previous action=1, Observation=[ 3.10813819e-01 -2.44909536e-04  1.16896946e-01  2.54690810e-01], Reward=1.0
# b
# Step 455: Previous action=1, Observation=[0.31080892 0.19303081 0.12199076 0.00104528], Reward=1.0
# b
# Step 456: Previous action=1, Observation=[ 0.31466954  0.38621122  0.12201167 -0.25079548], Reward=1.0
# b
# Step 457: Previous action=1, Observation=[ 0.32239376  0.57939874  0.11699576 -0.50263996], Reward=1.0
# b
# Step 458: Previous action=1, Observation=[ 0.33398174  0.77269413  0.10694296 -0.7562826 ], Reward=1.0
# b
# Step 459: Previous action=1, Observation=[ 0.34943562  0.96619228  0.09181731 -1.01349032], Reward=1.0
# b
# Step 460: Previous action=1, Observation=[ 0.36875946  1.1599775   0.0715475  -1.27598738], Reward=1.0
# b
# Step 461: Previous action=1, Observation=[ 0.39195901  1.35411781  0.04602775 -1.54543578], Reward=1.0
# b
# aa
# Step 462: Previous action=0, Observation=[ 0.41904137  1.15847421  0.01511904 -1.2387538 ], Reward=1.0
# b
# Step 463: Previous action=1, Observation=[ 0.44221085  1.35339874 -0.00965604 -1.52666234], Reward=1.0
# a
# Step 464: Previous action=0, Observation=[ 0.46927883  1.15839463 -0.04018929 -1.23700866], Reward=1.0
# a
# Step 465: Previous action=0, Observation=[ 0.49244672  0.96381144 -0.06492946 -0.95718202], Reward=1.0
# a
# Step 466: Previous action=0, Observation=[ 0.51172295  0.76961988 -0.0840731  -0.68558432], Reward=1.0
# a
# Step 467: Previous action=0, Observation=[ 0.52711535  0.5757595  -0.09778479 -0.42050923], Reward=1.0
# a
# Step 468: Previous action=0, Observation=[ 0.53863054  0.38214919 -0.10619497 -0.16018405], Reward=1.0
# a
# Step 469: Previous action=0, Observation=[ 0.54627352  0.18869519 -0.10939865  0.09719958], Reward=1.0
# a
# Step 470: Previous action=0, Observation=[ 0.55004743 -0.00470263 -0.10745466  0.35346301], Reward=1.0
# a
# Step 471: Previous action=0, Observation=[ 0.54995337 -0.19814563 -0.1003854   0.61042302], Reward=1.0
# a
# Step 472: Previous action=0, Observation=[ 0.54599046 -0.39173173 -0.08817694  0.86987652], Reward=1.0
# a
# Step 473: Previous action=0, Observation=[ 0.53815583 -0.58555067 -0.07077941  1.13358499], Reward=1.0
# a
# Step 474: Previous action=0, Observation=[ 0.52644481 -0.77967854 -0.04810771  1.40325594], Reward=1.0
# a
# Step 475: Previous action=0, Observation=[ 0.51085124 -0.9741711  -0.02004259  1.68051903], Reward=1.0
# a
# bb
# Step 476: Previous action=1, Observation=[ 0.49136782 -0.77882274  0.01356779  1.38166322], Reward=1.0
# b
# Step 477: Previous action=1, Observation=[ 0.47579136 -0.58387271  0.04120106  1.09325389], Reward=1.0
# b
# Step 478: Previous action=1, Observation=[ 0.46411391 -0.3893171   0.06306613  0.81377782], Reward=1.0
# b
# Step 479: Previous action=1, Observation=[ 0.45632757 -0.19511293  0.07934169  0.54157985], Reward=1.0
# b
# Step 480: Previous action=1, Observation=[ 0.45242531 -0.00119054  0.09017329  0.27491335], Reward=1.0
# b
# Step 481: Previous action=1, Observation=[0.4524015  0.19253688 0.09567155 0.01197787], Reward=1.0
# b
# Step 482: Previous action=1, Observation=[ 0.45625224  0.38616585  0.09591111 -0.24905282], Reward=1.0
# b
# Step 483: Previous action=1, Observation=[ 0.46397555  0.57979657  0.09093005 -0.51000938], Reward=1.0
# b
# Step 484: Previous action=1, Observation=[ 0.47557149  0.77352779  0.08072987 -0.77270906], Reward=1.0
# b
# Step 485: Previous action=1, Observation=[ 0.49104204  0.96745168  0.06527569 -1.0389387 ], Reward=1.0
# b
# Step 486: Previous action=1, Observation=[ 0.51039107  1.16164837  0.04449691 -1.31043594], Reward=1.0
# b
# Step 487: Previous action=1, Observation=[ 0.53362404  1.35617937  0.01828819 -1.58886584], Reward=1.0
# b
# aa
# Step 488: Previous action=0, Observation=[ 0.56074763  1.16084502 -0.01348912 -1.29053688], Reward=1.0
# a
# Step 489: Previous action=0, Observation=[ 0.58396453  0.96589718 -0.03929986 -1.0021074 ], Reward=1.0
# a
# Step 490: Previous action=0, Observation=[ 0.60328247  0.77132175 -0.05934201 -0.7220208 ], Reward=1.0
# a
# Step 491: Previous action=0, Observation=[ 0.61870891  0.57706868 -0.07378243 -0.44859041], Reward=1.0
# a
# Step 492: Previous action=0, Observation=[ 0.63025028  0.38306371 -0.08275423 -0.18004705], Reward=1.0
# a
# Step 493: Previous action=0, Observation=[ 0.63791156  0.18921746 -0.08635517  0.08542527], Reward=1.0
# a
# Step 494: Previous action=0, Observation=[ 0.64169591 -0.00456732 -0.08464667  0.34966241], Reward=1.0
# a
# Step 495: Previous action=0, Observation=[ 0.64160456 -0.19838981 -0.07765342  0.6144988 ], Reward=1.0
# a
# Step 496: Previous action=0, Observation=[ 0.63763676 -0.39234574 -0.06536345  0.8817488 ], Reward=1.0
# a
# Step 497: Previous action=0, Observation=[ 0.62978985 -0.58652188 -0.04772847  1.15318786], Reward=1.0
# a
# Step 498: Previous action=0, Observation=[ 0.61805941 -0.78098989 -0.02466471  1.43053084], Reward=1.0
# a
# Step 499: Previous action=0, Observation=[ 0.60243961 -0.97579882  0.0039459   1.71540467], Reward=1.0
# b
# Step 500: Previous action=1, Observation=[ 0.58292364 -0.78072235  0.038254    1.42395234], Reward=1.0
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# 사람은 Observation의 각 원소가 지니는 의미와 물리 법칙을 이용하여 코딩할 수 있지만 기계학습을 사용할 때 컴퓨터는 아무런 배경지식 없이 Action에 따라 Observation의 각 원소가 어떻게 변화하는지 학습합니다.
#
# 일반적인 아타리 게임에서는 딥러닝 모델이 그림을 분석하여 현재 상태에서 취할 수 있는 바람직한 액션을 선택합니다.<br>
# 수고하셨습니다.
