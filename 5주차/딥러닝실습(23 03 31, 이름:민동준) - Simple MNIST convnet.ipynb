# %% [markdown]
# # Simple MNIST convnet
# by uramoon@kw.ac.kr
#
# 원본 출처<br>
# **Author:** [fchollet](https://twitter.com/fchollet) (<a href="https://raw.githubusercontent.com/ronreiter/interactive-tutorials/master/LICENSE">Apache 2.0 License</a>)<br>
# **Date created:** 2015/06/19<br>
# **Last modified:** 2020/04/21<br>
# **Description:** A simple convnet that achieves ~99% test accuracy on MNIST.

# %% [markdown]
# 상단 메뉴 런타임 - 런타임 유형 변경에서 **GPU**를 선택하고 진행하세요.

# %% [markdown]
# ## Setup

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## TODO 1: Feature scaling

# %%
# Model / data parameters
num_classes = 10            # 레이블의 개수 (0, 1, 2, ..., 9, 10개) 
input_shape = (28, 28, 1)   # CNN은 2차원 정보를 활용합니다. (28 x 28 흑백 이미지 한 장, 기존 MLP는 784개 픽셀의 명암을 사용)

# the data, split between train and test sets
# X를 이미지, y를 이미지에 대한 레이블로 표현합니다.
# X_train[0]은 첫 번째 훈련 그림, y_train[0]은 첫 번째 훈련 그림의 정답 ([0, 9]에 속한 숫자 하나)
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# 각 픽셀 값을 [0, 255] -> [0, 1]로 변환하세요.
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255

# %% [markdown]
# ## TODO 2: Input shape

# %%
# 훈련용 이미지의 shape을 출력하세요. (6만장의 28 x 28 이미지)

X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %% [markdown]
# ## TODO 3: Shape expanding

# %%
# Make sure images have shape (28, 28, 1) 
# CNN은 한 장의 이미지 모양을 (가로, 세로, 채널 수)로 만들어야 합니다.
# 컬러 이미지는 R, G, B 세 장의 채널이지만 MNIST는 흑백이라 한 장의 채널이 필요합니다.
# 최종적으로 6만장의 28 x 28 이미지 흑백 채널 하나가 필요합니다.
# 가장 마지막 자리에 차원 하나 늘리기: (60000, 28, 28) -> (60000, 28, 28, 1), 
# 차원 늘리기 대신 reshape 함수도 사용 가능

# expand_dims는 NumPy 배열의 특정 위치에 차원을 늘려줍니다.
# 파이썬에서 인덱싱할 때 가장 마지막 위치를 나타내는 (음의) 정수를 기입하세요.
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)
print("X_train shape:", X_train.shape)
print(X_train.shape[0], "train samples")
print(X_test.shape[0], "test samples")
# Out:
# X_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Build the model

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"), # 3 by 3 크기로 이차원 이미지를 Scan 하는 유닛이 32개 있음
        layers.MaxPooling2D(pool_size=(2, 2)),                    # 2 by 2 크기의 이미지를 하나의 값으로 요약
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"), # 3 by 3 크기로 이차원 이미지를 Scan 하는 유닛이 64개 있음
        layers.MaxPooling2D(pool_size=(2, 2)),                    # 2 by 2 크기의 이미지를 하나의 값으로 요약
        layers.Flatten(),                                 # MLP에 사용되는 입력처럼 1차원 배열로 만들어주는 층
        layers.Dense(10, activation='softmax'),  # CNN의 출력층은 MLP와 동일합니다.
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##TODO 4: Model training

# %%
from tensorflow.keras.callbacks import EarlyStopping

batch_size = 128
epochs = 10000

model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

# TODO: 자유롭게 설정하세요.
# https://keras.io/api/callbacks/early_stopping/
es = EarlyStopping(patience=30, restore_best_weights=True)

# 훈련 데이터의 20%는 사용하지 않고 남겨두었다가 Epoch이 끝날 때마다 남겨둔 데이터로 성능을 평가하여 출력해보세요.
# 따로 테스트를 하지 않더라도 테스트 했을 때의 성능을 짐작할 수 있게 도와줍니다.
# Hint: https://keras.io/api/models/model_training_apis/ 에서 fit method 참조
model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, callbacks=es, validation_split=0.2)
# Out:
# Epoch 1/10000
# 375/375 [==============================] - 46s 118ms/step - loss: 0.2899 - accuracy: 0.9168 - val_loss: 0.0905 - val_accuracy: 0.9733
# Epoch 2/10000
# 375/375 [==============================] - 41s 109ms/step - loss: 0.0823 - accuracy: 0.9744 - val_loss: 0.0752 - val_accuracy: 0.9775
# Epoch 3/10000
# 375/375 [==============================] - 41s 108ms/step - loss: 0.0592 - accuracy: 0.9819 - val_loss: 0.0558 - val_accuracy: 0.9834
# Epoch 4/10000
# 375/375 [==============================] - 42s 111ms/step - loss: 0.0478 - accuracy: 0.9853 - val_loss: 0.0515 - val_accuracy: 0.9846
# Epoch 5/10000
# 375/375 [==============================] - 43s 114ms/step - loss: 0.0402 - accuracy: 0.9874 - val_loss: 0.0567 - val_accuracy: 0.9839
# Epoch 6/10000
# 375/375 [==============================] - 41s 109ms/step - loss: 0.0339 - accuracy: 0.9901 - val_loss: 0.0490 - val_accuracy: 0.9858
# Epoch 7/10000
# 375/375 [==============================] - 42s 112ms/step - loss: 0.0302 - accuracy: 0.9910 - val_loss: 0.0435 - val_accuracy: 0.9861
# Epoch 8/10000
# 375/375 [==============================] - 41s 108ms/step - loss: 0.0260 - accuracy: 0.9921 - val_loss: 0.0450 - val_accuracy: 0.9872
# Epoch 9/10000
# 375/375 [==============================] - 41s 110ms/step - loss: 0.0225 - accuracy: 0.9933 - val_loss: 0.0440 - val_accuracy: 0.9872
# Epoch 10/10000
# 375/375 [==============================] - 43s 114ms/step - loss: 0.0202 - accuracy: 0.9941 - val_loss: 0.0395 - val_accuracy: 0.9887
# Epoch 11/10000
# 375/375 [==============================] - 40s 106ms/step - loss: 0.0174 - accuracy: 0.9947 - val_loss: 0.0416 - val_accuracy: 0.9882
# Epoch 12/10000
# 375/375 [==============================] - 41s 109ms/step - loss: 0.0157 - accuracy: 0.9956 - val_loss: 0.0390 - val_accuracy: 0.9888
# Epoch 13/10000
# 375/375 [==============================] - 40s 108ms/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.0426 - val_accuracy: 0.9885
# Epoch 14/10000
# 375/375 [==============================] - 43s 116ms/step - loss: 0.0117 - accuracy: 0.9963 - val_loss: 0.0428 - val_accuracy: 0.9885
# Epoch 15/10000
# 375/375 [==============================] - 41s 109ms/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 0.0484 - val_accuracy: 0.9873
# Epoch 16/10000
# 375/375 [==============================] - 40s 108ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0430 - val_accuracy: 0.9894
# Epoch 17/10000
# 375/375 [==============================] - 41s 109ms/step - loss: 0.0079 - accuracy: 0.9977 - val_loss: 0.0474 - val_accuracy: 0.9876
# Epoch 18/10000
# 375/375 [==============================] - 42s 112ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.0467 - val_accuracy: 0.9885
# Epoch 19/10000
# 375/375 [==============================] - 43s 114ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0481 - val_accuracy: 0.9887
# Epoch 20/10000
# 375/375 [==============================] - 41s 108ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0525 - val_accuracy: 0.9879
# Epoch 21/10000
# 375/375 [==============================] - 41s 109ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0486 - val_accuracy: 0.9898
# Epoch 22/10000
# 375/375 [==============================] - 40s 108ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0550 - val_accuracy: 0.9889
# Epoch 23/10000
# 375/375 [==============================] - 40s 107ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0525 - val_accuracy: 0.9889
# Epoch 24/10000
# 375/375 [==============================] - 42s 112ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0488 - val_accuracy: 0.9899
# Epoch 25/10000
# 375/375 [==============================] - 41s 109ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0583 - val_accuracy: 0.9883
# Epoch 26/10000
# 375/375 [==============================] - 40s 107ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0567 - val_accuracy: 0.9894
# Epoch 27/10000
# 375/375 [==============================] - 41s 108ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0633 - val_accuracy: 0.9887
# Epoch 28/10000
# 375/375 [==============================] - 41s 108ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0610 - val_accuracy: 0.9896
# Epoch 29/10000
# 375/375 [==============================] - 41s 110ms/step - loss: 9.0097e-04 - accuracy: 0.9998 - val_loss: 0.0627 - val_accuracy: 0.9891
# Epoch 30/10000
# 375/375 [==============================] - 42s 111ms/step - loss: 6.7291e-04 - accuracy: 0.9998 - val_loss: 0.0618 - val_accuracy: 0.9895
# Epoch 31/10000
# 375/375 [==============================] - 41s 109ms/step - loss: 5.3076e-04 - accuracy: 0.9999 - val_loss: 0.0623 - val_accuracy: 0.9894
# Epoch 32/10000
# 375/375 [==============================] - 49s 131ms/step - loss: 3.7003e-04 - accuracy: 0.9999 - val_loss: 0.0628 - val_accuracy: 0.9901
# Epoch 33/10000
# 375/375 [==============================] - 42s 113ms/step - loss: 4.6854e-04 - accuracy: 0.9999 - val_loss: 0.0706 - val_accuracy: 0.9891
# Epoch 34/10000
# 375/375 [==============================] - 41s 110ms/step - loss: 2.5735e-04 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 0.9896
# Epoch 35/10000
# 375/375 [==============================] - 43s 115ms/step - loss: 1.3784e-04 - accuracy: 1.0000 - val_loss: 0.0709 - val_accuracy: 0.9888
# Epoch 36/10000
# 375/375 [==============================] - 47s 126ms/step - loss: 8.6169e-05 - accuracy: 1.0000 - val_loss: 0.0689 - val_accuracy: 0.9894
# Epoch 37/10000
# 375/375 [==============================] - 42s 111ms/step - loss: 4.0605e-05 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9892
# Epoch 38/10000
# 375/375 [==============================] - 41s 110ms/step - loss: 3.9783e-05 - accuracy: 1.0000 - val_loss: 0.0709 - val_accuracy: 0.9894
# Epoch 39/10000
# 375/375 [==============================] - 41s 109ms/step - loss: 2.3510e-05 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9889
# Epoch 40/10000
# 375/375 [==============================] - 41s 111ms/step - loss: 1.8984e-05 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9893
# Epoch 41/10000
# 375/375 [==============================] - 43s 114ms/step - loss: 1.7235e-05 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9893
# Epoch 42/10000
# 375/375 [==============================] - 43s 116ms/step - loss: 1.4488e-05 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9890

# %% [markdown]
# ## Evaluate the trained model
#
# Test 정확도가 99% 미만이면 TODO4부터 다시 수행하세요.

# %%
score = model.evaluate(X_test, y_test, verbose=0) # veerboase(mode) : 0 = silent(무음), 1 = progress bar(진행 표시줄), 2 = single line(단일 선)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.031711604446172714
# Test accuracy: 0.9900000095367432

# %% [markdown]
# ## 우리가 만든 테스트 데이터 읽어오기
# 좌측 파일 메뉴를 활용하여 test_images.npy, test_labels.npy 파일을 Colab에 업로드하세요.

# %%
our_test_images = np.load('our_test_images.npy')
our_test_labels = np.load('our_test_labels.npy')

# %% [markdown]
# 잘 읽어왔는지 9장을 무작위로 그려봅니다.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import random

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  rand = random.randint(0, len(our_test_images) - 1)
  plt.imshow(our_test_images[rand].reshape(28, 28))
  plt.title(our_test_labels[rand])
  plt.axis("off")

# %% [markdown]
# ## TODO5: 테스트 이미지 모양 변환

# %%
# TODO: 현재 our_test_images의 모양을 출력해봅시다.
our_test_images.shape
# Out:
# (30, 784)

# %%
# TODO: 우리가 만든 모델의 입력층에 들어갈 수 있도록 our_test_images 모양을 바꿔봅시다.
# Hint: reshape 함수를 사용하시면 쉽습니다.

print(our_test_images.shape)
our_test_images = our_test_images.reshape(30, 28, 28)
our_test_images = np.expand_dims(our_test_images, -1)
print(our_test_images.shape)

# print(our_test_images[0])
# Out:
# (30, 784)
# (30, 28, 28, 1)

# %% [markdown]
# ## TODO 6: 우리가 만든 테스트 데이터로 모델 평가
# evaluate 함수를 사용합니다. 예측이 잘 되나요?<br>
# 다음 시간에 이 문제를 해결할 것입니다.

# %%
score = model.evaluate(our_test_images, our_test_labels, verbose=0) # veerboase(mode) : 0 = silent(무음), 1 = progress bar(진행 표시줄), 2 = single line(단일 선)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 2.2349464893341064
# Test accuracy: 0.3333333432674408
